# %%
import pandas as pd
import numpy as np

# %%
import json

with open('D:/data/julia/2021-04-13-4mus-2nm-VCR stack (HAADF) 59.json') as data_file:    
    data = json.load(data_file)

# %%
data
# Out:
# {'md5': 'd81d4d5f8288176c4486f5ca678d19a1',
#  'num_frames': 34,
#  'shape_x': 512,
#  'shape_y': 512,
#  'boundary': 0.9093266739736606,
#  'path': '2021-04-13-4mus-2nm-VCR stack (HAADF) 59.tif',
#  '0': {'frame_index': 0,
#   'lattice_area_fraction': 0.0,
#   'defect_type': [],
#   'defect_x': [],
#   'defect_y': [],
#   'sampling': 0.03878522492379751},
#  '1': {'frame_index': 1,
#   'lattice_area_fraction': 0.02043846624159314,
#   'defect_type': [],
#   'defect_x': [],
#   'defect_y': [],
#   'sampling': 0.04020354207039448},
#  '2': {'frame_index': 2,
#   'lattice_area_fraction': 0.0,
#   'defect_type': [],
#   'defect_x': [],
#   'defect_y': [],
#   'sampling': 0.02452903052782842},
#  '3': {'frame_index': 3,
#   'lattice_area_fraction': 0.0206240719713512,
#   'defect_type': [],
#   'defect_x': [],
#   'defect_y': [],
#   'sampling': 0.03957190293506012},
#  '4': {'frame_index': 4,
#   'lattice_area_fraction': 0.0,
#   'defect_type': [],
#   'defect_x': [],
# ...

# %%
#defects_per_frame = []

areas = [data[str(i)]['lattice_area_fraction'] for i in range(data['num_frames'])]
first_frame = np.argmax(np.array(areas) > .5)


#data

#pd.read_json('D:/data/julia/2021-04-13-4mus-2nm-VCR stack (HAADF) 59.json')
# Out:
# 8
